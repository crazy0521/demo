# %%
pip install pymupdf
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pymupdf
#   Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl.metadata (24 kB)
# Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/19.2 MB 5.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.8/19.2 MB 5.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.6/19.2 MB 4.6 MB/s eta 0:00:04
#    ------ --------------------------------- 3.1/19.2 MB 3.9 MB/s eta 0:00:05
#    ------- -------------------------------- 3.7/19.2 MB 3.7 MB/s eta 0:00:05
#    -------- ------------------------------- 4.2/19.2 MB 3.2 MB/s eta 0:00:05
#    --------- ------------------------------ 4.5/19.2 MB 3.2 MB/s eta 0:00:05
#    --------- ------------------------------ 4.7/19.2 MB 3.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 5.2/19.2 MB 2.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.2/19.2 MB 2.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.5/19.2 MB 2.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.8/19.2 MB 2.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.8/19.2 MB 2.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.8/19.2 MB 2.3 MB/s eta 0:00:06
#    ------------ --------------------------- 6.0/19.2 MB 2.0 MB/s eta 0:00:07
#    ------------- -------------------------- 6.3/19.2 MB 1.8 MB/s eta 0:00:08
#    ------------- -------------------------- 6.3/19.2 MB 1.8 MB/s eta 0:00:08
#    ------------- -------------------------- 6.3/19.2 MB 1.8 MB/s eta 0:00:08
#    ------------- -------------------------- 6.6/19.2 MB 1.6 MB/s eta 0:00:08
#    ------------- -------------------------- 6.6/19.2 MB 1.6 MB/s eta 0:00:08
#    -------------- ------------------------- 6.8/19.2 MB 1.5 MB/s eta 0:00:09
#    -------------- ------------------------- 6.8/19.2 MB 1.5 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.2 MB 1.4 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.2 MB 1.4 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.2 MB 1.4 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.2 MB 1.4 MB/s eta 0:00:09
#    --------------- ------------------------ 7.3/19.2 MB 1.3 MB/s eta 0:00:10
#    --------------- ------------------------ 7.6/19.2 MB 1.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 7.9/19.2 MB 1.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 8.1/19.2 MB 1.2 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.4/19.2 MB 1.2 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.7/19.2 MB 1.3 MB/s eta 0:00:09
#    ------------------ --------------------- 8.9/19.2 MB 1.3 MB/s eta 0:00:09
#    ------------------- -------------------- 9.2/19.2 MB 1.2 MB/s eta 0:00:09
#    ------------------- -------------------- 9.2/19.2 MB 1.2 MB/s eta 0:00:09
#    -------------------- ------------------- 9.7/19.2 MB 1.2 MB/s eta 0:00:08
#    -------------------- ------------------- 10.0/19.2 MB 1.2 MB/s eta 0:00:08
#    -------------------- ------------------- 10.0/19.2 MB 1.2 MB/s eta 0:00:08
#    --------------------- ------------------ 10.2/19.2 MB 1.2 MB/s eta 0:00:08
#    --------------------- ------------------ 10.5/19.2 MB 1.2 MB/s eta 0:00:08
#    ---------------------- ----------------- 10.7/19.2 MB 1.2 MB/s eta 0:00:07
#    ---------------------- ----------------- 11.0/19.2 MB 1.2 MB/s eta 0:00:07
#    ---------------------- ----------------- 11.0/19.2 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.3/19.2 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.3/19.2 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.5/19.2 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.5/19.2 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.5/19.2 MB 1.2 MB/s eta 0:00:07
#    ------------------------ --------------- 11.8/19.2 MB 1.1 MB/s eta 0:00:07
#    ------------------------- -------------- 12.1/19.2 MB 1.1 MB/s eta 0:00:07
#    ------------------------- -------------- 12.1/19.2 MB 1.1 MB/s eta 0:00:07
#    ------------------------- -------------- 12.3/19.2 MB 1.1 MB/s eta 0:00:07
#    ------------------------- -------------- 12.3/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.6/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.6/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.6/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.6/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.6/19.2 MB 1.1 MB/s eta 0:00:07
#    -------------------------- ------------- 12.8/19.2 MB 1.0 MB/s eta 0:00:07
#    -------------------------- ------------- 12.8/19.2 MB 1.0 MB/s eta 0:00:07
#    --------------------------- ------------ 13.1/19.2 MB 995.2 kB/s eta 0:00:07
#    --------------------------- ------------ 13.1/19.2 MB 995.2 kB/s eta 0:00:07
#    --------------------------- ------------ 13.1/19.2 MB 995.2 kB/s eta 0:00:07
#    --------------------------- ------------ 13.4/19.2 MB 973.1 kB/s eta 0:00:07
#    --------------------------- ------------ 13.4/19.2 MB 973.1 kB/s eta 0:00:07
#    ---------------------------- ----------- 13.6/19.2 MB 959.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 13.9/19.2 MB 956.6 kB/s eta 0:00:06
#    ----------------------------- ---------- 14.2/19.2 MB 961.3 kB/s eta 0:00:06
#    ----------------------------- ---------- 14.4/19.2 MB 965.8 kB/s eta 0:00:06
#    ------------------------------- -------- 14.9/19.2 MB 984.8 kB/s eta 0:00:05
#    ------------------------------- -------- 15.2/19.2 MB 992.0 kB/s eta 0:00:05
#    -------------------------------- ------- 15.7/19.2 MB 1.0 MB/s eta 0:00:04
#    --------------------------------- ------ 16.0/19.2 MB 1.0 MB/s eta 0:00:04
#    ----------------------------------- ---- 17.0/19.2 MB 1.1 MB/s eta 0:00:03
#    ------------------------------------ --- 17.6/19.2 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 17.8/19.2 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 18.1/19.2 MB 1.1 MB/s eta 0:00:02
#    -------------------------------------- - 18.4/19.2 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.27.2.3

# %%
import fitz
import os
import re

# %%
class Resume:
    def __init__(self,filename,text):
       self.filename = filename
       self.text = text

students = []

# %%
def extract_text(filename):
    text = ""
    doc = fitz.open(filename)
    for page in doc:
        text = text + page.get_text()
    return text

# %%
folder_path = "./resume"
filenames = os.listdir(folder_path)
print(filenames)
# Out:
# ['1.txt', '2.txt', '3.txt']

# %%
for filename in filenames:
    text = extract_text(f"{folder_path}/{filename}")
    student = Resume(filename,text)
    students.append(student)

# %%
for student in students:
    print(student.filename)
    print(student.text)
    email = re.search(r'\S+@\S+', student.text).group()
    print(email)
# Out:
# 1.txt
# Name: Yash Maske
# Email: yash.maske@email.com
# Phone: +91 9876543210
# Education:
# Bachelor of Technology in Computer Science
# XYZ Engineering College, Pune
# 2021 - 2025
# Skills:
# - Python
# - Data Structures
# - SQL
# - Machine Learning Basics
# Projects:
# - Student Result Analysis using Python
# - Resume Screening Tool using NLP
# Internship:
# Software Development Intern at ABC Tech
# June 2024 - August 2024
# Strengths:
# - Problem Solving
# - Team Collaboration
# - Quick Learner
#
# yash.maske@email.com
# 2.txt
# Name: Shubhankar Jakate
# Email: aman.patel@email.com
# Phone: +91 9325815724
# Education:
# Bachelor of Technology in Artificial Intelligence
# DEF University, Bangalore
# 2021 - 2025
# Skills:
# - Python
# - Machine Learning
# - Deep Learning
# - Pandas, NumPy
# - NLP Basics
# Projects:
# - Chatbot using NLP
# - Resume Ranking System using ML
# Achievements:
# - Hackathon Runner-Up (AI Track)
# - Kaggle Competition Participant
# Strengths:
# - Research Oriented
# - Creative Thinking
# - Strong Coding Skills
#
# aman.patel@email.com
# 3.txt
# Name: Priya Verma
# Email: priyaverma@email.com
# Phone: +91 9123456789
# Education:
# Bachelor of Engineering in Information Technology
# LMN Institute of Technology, Mumbai
# 2020 - 2024
# Skills:
# - Java
# - OOP Concepts
# - Web Development (HTML, CSS, JavaScript)
# - MySQL
# Projects:
# - Online Voting System
# - E-commerce Website
# Certifications:
# - Java Programming Certification
# - Web Development Bootcamp
# Strengths:
# - Leadership
# - Communication Skills
# - Analytical Thinking
#
# priyaverma@email.com

# %%
import hashlib

# %%
class Block:
  def __init__(self, data, prev_hash):
    self.data = data
    self.prev_hash = prev_hash
    self.hash = self.calc_hash()

  def calc_hash(self):
    sha = hashlib.sha256()
    sha.update(self.data.encode('utf-8'))
    return sha.hexdigest()

# %%
class Blockchain:

  def __init__(self):
    self.chain = [self.create_genesis_block()]

  
  def create_genesis_block(self):
    return Block("This is the genesis block", "0")

  
  def add_block(self, data):
    prev_block = self.chain[-1]
    new_block = Block(data, prev_block.hash)
    self.chain.append(new_block)

# %%
blockchain = Blockchain()

# %%
for student in students:
    blockchain.add_block(student.text)

# %%
print("Blockchain:")

for block in blockchain.chain:
    print('Data :',block.data)
    print('Privious Hash :', block.prev_hash)
    print('Hash :', block.hash)
    print("**********************************************************************************************************************************************************************")
# Out:
# Blockchain:
# Data : This is the genesis block
# Privious Hash : 0
# Hash : 182af1c8e7371cf31550abdf82208288ec41122cdb0955c2c3e0583feb5bb883
# **********************************************************************************************************************************************************************
# Data : Name: Yash Maske
# Email: yash.maske@email.com
# Phone: +91 9876543210
# Education:
# Bachelor of Technology in Computer Science
# XYZ Engineering College, Pune
# 2021 - 2025
# Skills:
# - Python
# - Data Structures
# - SQL
# - Machine Learning Basics
# Projects:
# - Student Result Analysis using Python
# - Resume Screening Tool using NLP
# Internship:
# Software Development Intern at ABC Tech
# June 2024 - August 2024
# Strengths:
# - Problem Solving
# - Team Collaboration
# - Quick Learner
#
# Privious Hash : 182af1c8e7371cf31550abdf82208288ec41122cdb0955c2c3e0583feb5bb883
# Hash : c3690349be30ac9c3975464f87c8d35e240c0c7604b41c1da7a65085f1b62d98
# **********************************************************************************************************************************************************************
# Data : Name: Shubhankar Jakate
# Email: aman.patel@email.com
# Phone: +91 9325815724
# Education:
# Bachelor of Technology in Artificial Intelligence
# DEF University, Bangalore
# 2021 - 2025
# Skills:
# - Python
# - Machine Learning
# - Deep Learning
# - Pandas, NumPy
# - NLP Basics
# Projects:
# - Chatbot using NLP
# - Resume Ranking System using ML
# Achievements:
# - Hackathon Runner-Up (AI Track)
# - Kaggle Competition Participant
# Strengths:
# - Research Oriented
# - Creative Thinking
# - Strong Coding Skills
#
# Privious Hash : c3690349be30ac9c3975464f87c8d35e240c0c7604b41c1da7a65085f1b62d98
# Hash : 3005b0602c8933e89d454c95dfcf871aae0d698b44cb0472691a9b26687d63a1
# **********************************************************************************************************************************************************************
# Data : Name: Priya Verma
# Email: priyaverma@email.com
# Phone: +91 9123456789
# Education:
# Bachelor of Engineering in Information Technology
# LMN Institute of Technology, Mumbai
# 2020 - 2024
# Skills:
# - Java
# - OOP Concepts
# - Web Development (HTML, CSS, JavaScript)
# - MySQL
# Projects:
# - Online Voting System
# - E-commerce Website
# Certifications:
# - Java Programming Certification
# - Web Development Bootcamp
# Strengths:
# - Leadership
# - Communication Skills
# - Analytical Thinking
#
# Privious Hash : 3005b0602c8933e89d454c95dfcf871aae0d698b44cb0472691a9b26687d63a1
# Hash : 1732b18ab9f1f77580cf4241b9602ced27b9d70e0767b26a979f58312bcf0191
# **********************************************************************************************************************************************************************
